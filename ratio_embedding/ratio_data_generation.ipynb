# %%
import numpy as np
import pandas as pd
# import torch

N = 100
solv_num = 6

solv_embedding = np.random.randn(N, 10)
target_embedding = np.random.randn(N, 3)
# Out:
# Running cells with 'solv (Python 3.12.11)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'conda install -n solv ipykernel --update-deps --force-reinstall'

# %%
formula_solv_ids = {i: [np.random.randint(0, N) for j in range(solv_num)] for i in range(137)}
formula_ratio_ids = {i: np.random.rand(solv_num) for i in range(137)}
